# %%
#import libraries
import pandas as pd
import numpy as np
from matplotlib import pyplot as plt
import seaborn as sns
# %matplotlib inline

# %%
#load csv file data with headers
location = "Sandy/datasets/housesalesprediction/kc_house_data.csv"
df = pd.read_csv(location)

# %%
df.head()
# Out:
#            id             date     price  bedrooms  bathrooms  sqft_living  \
# 0  7129300520  20141013T000000  221900.0         3       1.00         1180
# 1  6414100192  20141209T000000  538000.0         3       2.25         2570
# 2  5631500400  20150225T000000  180000.0         2       1.00          770
# 3  2487200875  20141209T000000  604000.0         4       3.00         1960
# 4  1954400510  20150218T000000  510000.0         3       2.00         1680
#
#    sqft_lot  floors  waterfront  view     ...      grade  sqft_above  \
# 0      5650     1.0           0     0     ...          7        1180
# 1      7242     2.0           0     0     ...          7        2170
# 2     10000     1.0           0     0     ...          6         770
# 3      5000     1.0           0     0     ...          7        1050
# 4      8080     1.0           0     0     ...          8        1680
#
#    sqft_basement  yr_built  yr_renovated  zipcode      lat     long  \
# ...

# %%
#show the column names in the dataset
df.columns
# Out:
# Index(['id', 'date', 'price', 'bedrooms', 'bathrooms', 'sqft_living',
#        'sqft_lot', 'floors', 'waterfront', 'view', 'condition', 'grade',
#        'sqft_above', 'sqft_basement', 'yr_built', 'yr_renovated', 'zipcode',
#        'lat', 'long', 'sqft_living15', 'sqft_lot15'],
#       dtype='object')

# %%
df.describe()
# Out:
#                  id         price      bedrooms     bathrooms   sqft_living  \
# count  2.161300e+04  2.161300e+04  21613.000000  21613.000000  21613.000000
# mean   4.580302e+09  5.400881e+05      3.370842      2.114757   2079.899736
# std    2.876566e+09  3.671272e+05      0.930062      0.770163    918.440897
# min    1.000102e+06  7.500000e+04      0.000000      0.000000    290.000000
# 25%    2.123049e+09  3.219500e+05      3.000000      1.750000   1427.000000
# 50%    3.904930e+09  4.500000e+05      3.000000      2.250000   1910.000000
# 75%    7.308900e+09  6.450000e+05      4.000000      2.500000   2550.000000
# max    9.900000e+09  7.700000e+06     33.000000      8.000000  13540.000000
#
#            sqft_lot        floors    waterfront          view     condition  \
# count  2.161300e+04  21613.000000  21613.000000  21613.000000  21613.000000
# mean   1.510697e+04      1.494309      0.007542      0.234303      3.409430
# ...

# %%
#make a scatterplot (both variables need to be numeric?)
sns.lmplot(x='bathrooms', y='price', data=df)

# %%
#add more details to scatterplot
sns.lmplot(x='bathrooms', y='price', data=df, 
           fit_reg=False, #remove regression line
           hue='zipcode')   #color by evolution stage

# %%
df['bathrooms'].value_counts()
# Out:
# 2.50    5380
# 1.00    3852
# 1.75    3048
# 2.25    2047
# 2.00    1930
# 1.50    1446
# 2.75    1185
# 3.00     753
# 3.50     731
# 3.25     589
# 3.75     155
# 4.00     136
# 4.50     100
# 4.25      79
# 0.75      72
# 4.75      23
# 5.00      21
# 5.25      13
# 0.00      10
# 5.50      10
# 1.25       9
# 6.00       6
# 0.50       4
# 5.75       4
# 8.00       2
# 6.25       2
# 6.50       2
# 6.75       2
# 7.50       1
# 7.75       1
# Name: bathrooms, dtype: int64

# %%
df['zipcode'].value_counts()
# Out:
# 98103    602
# 98038    590
# 98115    583
# 98052    574
# 98117    553
# 98042    548
# 98034    545
# 98118    508
# 98023    499
# 98006    498
# 98133    494
# 98059    468
# 98058    455
# 98155    446
# 98074    441
# 98033    432
# 98027    412
# 98125    410
# 98056    406
# 98053    405
# 98001    362
# 98075    359
# 98126    354
# 98092    351
# 98144    343
# 98106    335
# 98116    330
# 98029    321
# 98004    317
# 98199    317
#         ...
# 98168    269
# 98112    269
# 98055    268
# 98107    266
# 98136    263
# 98178    262
# 98030    256
# 98177    255
# 98166    254
# 98022    234
# 98105    229
# 98045    221
# 98002    199
# 98077    198
# 98011    195
# 98019    190
# 98108    186
# 98119    184
# 98005    168
# 98007    141
# 98188    136
# 98032    125
# 98014    124
# 98070    118
# 98109    109
# 98102    105
# 98010    100
# 98024     81
# 98148     57
# 98039     50
# Name: zipcode, Length: 70, dtype: int64

# %%
df.describe()
# Out:
#                  id         price      bedrooms     bathrooms   sqft_living  \
# count  2.161300e+04  2.161300e+04  21613.000000  21613.000000  21613.000000
# mean   4.580302e+09  5.400881e+05      3.370842      2.114757   2079.899736
# std    2.876566e+09  3.671272e+05      0.930062      0.770163    918.440897
# min    1.000102e+06  7.500000e+04      0.000000      0.000000    290.000000
# 25%    2.123049e+09  3.219500e+05      3.000000      1.750000   1427.000000
# 50%    3.904930e+09  4.500000e+05      3.000000      2.250000   1910.000000
# 75%    7.308900e+09  6.450000e+05      4.000000      2.500000   2550.000000
# max    9.900000e+09  7.700000e+06     33.000000      8.000000  13540.000000
#
#            sqft_lot        floors    waterfront          view     condition  \
# count  2.161300e+04  21613.000000  21613.000000  21613.000000  21613.000000
# mean   1.510697e+04      1.494309      0.007542      0.234303      3.409430
# ...

# %%
# 1. Draw the map background
fig = plt.figure(figsize=(8, 8))
m = Basemap(projection='lcc', resolution='h', 
            lat_0=37.5, lon_0=-119,
            width=1E6, height=1.2E6)
m.shadedrelief()
m.drawcoastlines(color='gray')
m.drawcountries(color='gray')
m.drawstates(color='gray')

# 2. scatter city data, with color reflecting population
# and size reflecting area
m.scatter(lon, lat, latlon=True,
          c=np.log10(population), s=area,
          cmap='Reds', alpha=0.5)

# 3. create colorbar and legend
plt.colorbar(label=r'$\log_{10}({\rm population})$')
plt.clim(3, 7)

# make legend with dummy points
for a in [100, 300, 500]:
    plt.scatter([], [], c='k', alpha=0.5, s=a,
                label=str(a) + ' km$^2$')
plt.legend(scatterpoints=1, frameon=False,
           labelspacing=1, loc='lower left');
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-16-8ae2516e5dc6> in <module>()
#       1 # 1. Draw the map background
#       2 fig = plt.figure(figsize=(8, 8))
# ----> 3 m = Basemap(projection='lcc', resolution='h',
#       4             lat_0=37.5, lon_0=-119,
#       5             width=1E6, height=1.2E6)
#
# NameError: name 'Basemap' is not defined

# %%
new1925 = df[(df['bathrooms'] > 2) & (df['bedrooms'] > 3 ) & (df['yr_built'] < 1925)]
new1925
# Out:
#                id             date      price  bedrooms  bathrooms  \
# 125    4389200955  20150302T000000  1450000.0         4       2.75
# 209    6300000550  20140717T000000   464000.0         6       3.00
# 282    7424700045  20150513T000000  2050000.0         5       3.00
# 312    1860600135  20140502T000000  2384000.0         5       2.50
# 432    3454000060  20140722T000000  1000000.0         4       2.50
# 518    4386700135  20141114T000000  2250000.0         4       2.25
# 573    1189000030  20140603T000000   650000.0         5       2.75
# 779    1954700695  20140612T000000  2250000.0         5       4.25
# 884    7871500070  20140603T000000   930000.0         4       2.50
# 940    2768301715  20150311T000000   565000.0         4       3.00
# 942      65000400  20141022T000000   570000.0         4       3.00
# 944    8712100575  20140828T000000   915000.0         5       2.50
# 955    5489200435  20140904T000000   550000.0         4       3.00
# ...

# %%
plt.subplots(figsize=(30,7))
sns.violinplot(x='yr_built',y='bathrooms',data=new1925)

# %%
new2000 = df[(df['bathrooms'] > 2) & (df['bedrooms'] > 3 ) & (df['yr_built'] >1999)]
new2000
# Out:
#                id             date      price  bedrooms  bathrooms  \
# 5      7237550310  20140512T000000  1225000.0         4       4.50
# 29     1873100390  20150302T000000   719000.0         4       2.50
# 40     5547700270  20140715T000000   625000.0         4       2.50
# 42     7203220400  20140707T000000   861990.0         5       2.75
# 56     9478500640  20140819T000000   292500.0         4       2.50
# 67     3717000160  20141009T000000   287000.0         4       2.50
# 73     5416510140  20140710T000000   360000.0         4       2.50
# 79     1531000030  20150323T000000   720000.0         4       2.50
# 91     5036300431  20150311T000000  1099880.0         5       2.75
# 114    8961960160  20141028T000000   480000.0         4       2.50
# 129    7853210060  20150406T000000   430000.0         4       2.50
# 134    2767602356  20150126T000000   675000.0         4       3.50
# 153    7855801670  20150401T000000  2250000.0         4       3.25
# ...

# %%
plt.subplots(figsize=(30,7))
sns.violinplot(x='yr_built',y='bathrooms',data=new2000)
